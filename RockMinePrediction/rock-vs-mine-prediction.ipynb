# %% [markdown]
# <div style="padding:20px;
#             color:#150d0a;
#             margin:10px;
#             font-size:220%;
#             text-align:center;
#             display:fill;
#             border-radius:20px;
#             border-width: 5px;
#             border-style: solid;
#             border-color: #150d0a;
#             background-color:#eca912;
#             overflow:hidden;
#             font-weight:500">Rock vs Mine Prediction</div>

# %% [markdown]
# <h1 style="color:blue;text-align:center;">Importing the Dependencies</h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# <h1 style="color:blue;text-align:center;">Data Collection and Data Preprocessing</h1>

# %%
sonar_data = pd.read_csv("/kaggle/input/sonar-data/Sonar-Data.csv", header=None) #header = None is done because the header row is not there

# %%
sonar_data.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# ...

# %%
sonar_data.shape
# Out:
# (208, 61)

# %%
sonar_data.describe()
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %% [markdown]
# ## Getting the number of values of Rock and Mine

# %%
sonar_data[60].value_counts() # to know number of Rock(R) and Mine(M), they are in 60th column
# Out:
# M    111
# R     97
# Name: 60, dtype: int64

# %%
sonar_data.groupby(60).mean()
# Out:
#           0         1         2         3         4         5         6   \
# 60
# M   0.034989  0.045544  0.050720  0.064768  0.086715  0.111864  0.128359
# R   0.022498  0.030303  0.035951  0.041447  0.062028  0.096224  0.114180
#
#           7         8         9   ...        50        51        52        53  \
# 60                                ...
# M   0.149832  0.213492  0.251022  ...  0.019352  0.016014  0.011643  0.012185
# R   0.117596  0.137392  0.159325  ...  0.012311  0.010453  0.009640  0.009518
#
#           54        55        56        57        58        59
# 60
# M   0.009923  0.008914  0.007825  0.009060  0.008695  0.006930
# R   0.008567  0.007430  0.007814  0.006677  0.007078  0.006024
#
# [2 rows x 60 columns]

# %% [markdown]
# ## Separating Data and Label ('R' and 'M' column)

# %%
X = sonar_data.drop(columns = 60, axis = 1)
Y = sonar_data[60]

# %%
print(X)
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
print(Y)
# Out:
# 0      R
# 1      R
# 2      R
# 3      R
# 4      R
#       ..
# 203    M
# 204    M
# 205    M
# 206    M
# 207    M
# Name: 60, Length: 208, dtype: object

# %% [markdown]
# <h1 style="color:blue;text-align:center;">Training and Test Data</h1>

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.1, random_state=6)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (208, 60) (187, 60) (21, 60)

# %% [markdown]
# <h1 style="color:blue;text-align:center;">Model Training</h1>

# %%
model = LogisticRegression()

# %% [markdown]
# ## Training the Logistic Regression Model with training data

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# <h1 style="color:blue;text-align:center;">Model Evaluation</h1>

# %% [markdown]
# ## Accuracy on training data

# %%
XTrainPred = model.predict(X_train)
TrainDataAccuracy = accuracy_score(XTrainPred, Y_train)
TrainDataAccuracy
# Out:
# 0.8449197860962567

# %%
XTestPred = model.predict(X_test)
TestDataAccuracy = accuracy_score(XTestPred, Y_test)
TestDataAccuracy
# Out:
# 0.8095238095238095

# %% [markdown]
# <h1 style="color:blue;text-align:center;">Making a Predictive System</h1>

# %%
InputData = (0.0201,0.0423,0.0554,0.0783,0.0620,0.0871,0.1201,0.2707,0.1206,0.0279,0.2251,0.2615,0.1770,0.3709,0.4533,0.5553,0.4616,0.3797,0.3450,0.2665,0.2395,0.1127,0.2556,0.5169,0.3779,0.4082,0.5353,0.5116,0.4544,0.4258,0.3869,0.3939,0.4661,0.3974,0.2194,0.1816,0.1023,0.2108,0.3253,0.3697,0.2912,0.3010,0.2563,0.1927,0.2062,0.1751,0.0841,0.1035,0.0641,0.0153,0.0081,0.0191,0.0182,0.0160,0.0290,0.0090,0.0242,0.0224,0.0190,0.0096)

# Changing the InputData to a numpy array
InputData2NumoyArray = np.array(InputData)

# reshape the numpy array as we are predicting for one instance
InputDataReshaped = InputData2NumoyArray.reshape(1,-1)

Prediction = model.predict(InputDataReshaped)

#Prediction

if(Prediction[0]=='R'): # used 0 since output is in list has only one column and the index of that column is 0
    print("The object is Rock")
else:
    print("The object is Mine")
# Out:
# The object is Rock

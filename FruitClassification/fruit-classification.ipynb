# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from pandas.plotting import scatter_matrix
from matplotlib import cm
plt.style.use("dark_background")

# %%
df = pd.read_table("/kaggle/input/fruit-data-with-colors/fruit_data_with_colors.txt")

# %%
df.shape
# Out:
# (59, 7)

# %%
df.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
df['fruit_name'].unique()
# Out:
# array(['apple', 'mandarin', 'orange', 'lemon'], dtype=object)

# %%
df.groupby('fruit_name').size()
# Out:
# fruit_name
# apple       19
# lemon       16
# mandarin     5
# orange      19
# dtype: int64

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='fruit_name', data=df, palette='flare'); #for categorical data
plt.title("Fruits")
plt.show()

# %%
df.drop('fruit_label', axis=1).plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False, figsize=(5,5), title=('Box plot for each variable'), color='red')
plt.show()

# %%
df.drop('fruit_label' ,axis=1).hist(bins=40, figsize=(5,5), color='red')
plt.suptitle("Histogram for each numeric input variable")
# Out:
# Text(0.5, 0.98, 'Histogram for each numeric input variable')

# %%
Features = ['mass', 'width', 'height', 'color_score']
X = df[feature_names]
y = df['fruit_label']

cmap = cm.get_cmap('summer') #cmap is colormap
scatter = pd.plotting.scatter_matrix(X, c = y, marker = 'o', s=40, hist_kwds={'bins':15}, figsize=(9,9), cmap = cmap,)
plt.suptitle('Scatter Matrix for Each Input Variable')

# %%
df.describe()
# Out:
#        fruit_label        mass      width     height  color_score
# count    59.000000   59.000000  59.000000  59.000000    59.000000
# mean      2.542373  163.118644   7.105085   7.693220     0.762881
# std       1.208048   55.018832   0.816938   1.361017     0.076857
# min       1.000000   76.000000   5.800000   4.000000     0.550000
# 25%       1.000000  140.000000   6.600000   7.200000     0.720000
# 50%       3.000000  158.000000   7.200000   7.600000     0.750000
# 75%       4.000000  177.000000   7.500000   8.200000     0.810000
# max       4.000000  362.000000   9.600000  10.500000     0.930000
